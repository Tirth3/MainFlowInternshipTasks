# %%
# !python -m pip install --upgrade pip
# !pip install pandas

# %%
import pandas as pd

df = pd.read_csv("Superstore.csv",encoding='windows-1254')
df.isnull().sum()
# df.shape
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
df.drop_duplicates()
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 1          2  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 2          3  CA-2016-138688   6/12/2016   6/16/2016    Second Class
# 3          4  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# 4          5  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# ...      ...             ...         ...         ...             ...
# 9989    9990  CA-2014-110422   1/21/2014   1/23/2014    Second Class
# 9990    9991  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9991    9992  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9992    9993  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9993    9994  CA-2017-119914    5/4/2017    5/9/2017    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# ...

# %%
import matplotlib.pyplot as plt

# outlier box plot 
df['Profit'].plot(kind='box', title='Sales of product') 
plt.show()

# %%
df['Profit'].describe()
# Out:
# count    9994.000000
# mean       28.656896
# std       234.260108
# min     -6599.978000
# 25%         1.728750
# 50%         8.666500
# 75%        29.364000
# max      8399.976000
# Name: Profit, dtype: float64

# %%
Q1 = df['Profit'].quantile(0.25)
Q3 = df['Profit'].quantile(0.75)
IQR = Q3 - Q1
print(IQR)

lower_limit = Q1 - 1.5 * IQR
upper_limit = Q3 + 1.5 * IQR
print(lower_limit)
print(upper_limit)
# Out:
# 27.63525
# -39.724125
# 70.816875

# %%
outliers_low = (lower_limit > df['Profit'])
outliers_up = (upper_limit < df['Profit'])

# %%
df['Profit'][~(outliers_low | outliers_up)]
# Out:
# 0       41.9136
# 2        6.8714
# 4        2.5164
# 5       14.1694
# 6        1.9656
#          ...
# 9988    55.6470
# 9989     4.1028
# 9990    15.6332
# 9991    19.3932
# 9992    13.3200
# Name: Profit, Length: 8113, dtype: float64

# %%
df = df[~(outliers_low | outliers_up)]
df
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 2          3  CA-2016-138688   6/12/2016   6/16/2016    Second Class
# 4          5  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# 5          6  CA-2014-115812    6/9/2014   6/14/2014  Standard Class
# 6          7  CA-2014-115812    6/9/2014   6/14/2014  Standard Class
# ...      ...             ...         ...         ...             ...
# 9988    9989  CA-2017-163629  11/17/2017  11/21/2017  Standard Class
# 9989    9990  CA-2014-110422   1/21/2014   1/23/2014    Second Class
# 9990    9991  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9991    9992  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9992    9993  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# ...

# %%
mean = df['Profit'].mean()
median = df['Profit'].median()
standard_deviation = df['Profit'].std()
variance = df['Profit'].var()

print("Mean of profit : " + str(mean))
print("Median of profit : " + str(median))
print("Standard deviation of profit : " + str(standard_deviation))
print("Variance of profit : " + str(variance))
# Out:
# Mean of profit : 11.604085985455443
# Median of profit : 7.2576
# Standard deviation of profit : 18.641424792714822
# Variance of profit : 347.5027183024429

# %%
correlation_sales_profit = df['Profit'].corr(df['Sales'])
print("Correlation coefficient between profit and sales : " + str(correlation_sales_profit))
# Out:
# Correlation coefficient between profit and sales : 0.3223091739535829

# %%
df['Profit'].hist()
# Out:
# <Axes: >

# %%
corr = df.corr(numeric_only=True)
corr.style.background_gradient(cmap ='coolwarm')
# Out:
# <style type="text/css">
# #T_2f631_row0_col0, #T_2f631_row1_col1, #T_2f631_row2_col2, #T_2f631_row3_col3, #T_2f631_row4_col4, #T_2f631_row5_col5 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_2f631_row0_col1, #T_2f631_row2_col0, #T_2f631_row3_col0 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_2f631_row0_col2 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_2f631_row0_col3, #T_2f631_row4_col2, #T_2f631_row4_col5, #T_2f631_row5_col0, #T_2f631_row5_col1, #T_2f631_row5_col4 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_2f631_row0_col4 {
#   background-color: #a2c1ff;
#   color: #000000;
# }
# #T_2f631_row0_col5 {
#   background-color: #9bbcff;
#   color: #000000;
# }
# #T_2f631_row1_col0, #T_2f631_row1_col3, #T_2f631_row4_col0 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_2f631_row1_col2 {
#   background-color: #5b7ae5;
#   color: #f1f1f1;
# }
# #T_2f631_row1_col4 {
#   background-color: #aac7fd;
# ...
